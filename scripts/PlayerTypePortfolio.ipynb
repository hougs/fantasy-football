# %%
import pandas as pd

# %%
te_df = pd.read_csv("/home/juliet/src/football/data/superNovaOut/TE.txt", header=None, sep="\t",
                    names=["pid", "season", "totalPts", "stdDev"])
te_df[te_df.season==2014][["pid", "totalPts", "stdDev"]]
# Out:
#           pid  totalPts      stdDev
# 13    AC-1650         0    0.000000
# 32    AF-0200      1134   58.917315
# 44    AG-0500      3506  126.513818
# 62    AQ-0100      1208   54.125255
# 66    AR-1160       278   46.073914
# 67    AS-0550       206   40.374482
# 100   BB-2450       252   63.000000
# 108   BC-0700       446   30.189958
# 149   BL-0950       268   43.632978
# 173   BM-3800       104    4.265952
# 181   BP-0200       252   63.000000
# 191   BP-0600        42    2.642797
# 219   BW-0700       574   44.397152
# 224   BW-2030        22    2.400000
# 237   CB-2775         5    0.000000
# 241   CC-2100       554   54.164715
# 253   CC-3200       288   44.263416
# 274   CF-0375       133   51.207812
# 284   CF-0650      2512   89.484427
# 286   CF-0850       400   41.983330
# 290   CG-1030       274   45.215554
# 292   CG-1650       312   52.804672
# 297   CH-1200       420   46.185616
# 300   CH-1230       280   42.184120
# 301   CH-2350       572   52.642986
# ...

# %%
rb_df = pd.read_csv("/home/juliet/src/football/data/superNovaOut/RB.txt", header=None, sep="\t",
                    names=["pid", "season", "totalPts", "stdDev"])
rb_df[rb_df.season==2014][["pid", "totalPts", "stdDev"]]
# Out:
#           pid  totalPts      stdDev
# 0     AA-0562         3    0.000000
# 6     AB-1975       524   51.858582
# 15    AB-2600      2434   96.613715
# 37    AD-1300       774   47.403593
# 41    AE-0750      1864   85.367181
# 47    AF-0900      4360  112.415701
# 79    AM-2850      2694   91.320328
# 93    AP-0700        54    0.000000
# 121   AS-0900       292   36.650911
# 125   AS-1800        14    2.624669
# 129   AS-2300      1462   71.365888
# 156   AW-1350      1124   67.405026
# 180   BB-2250       314   38.520254
# 186   BB-3350       168    8.383658
# 193   BC-3070      1346   55.912285
# 240   BL-0900         8    0.000000
# 246   BM-2600       612   44.213536
# 254   BO-0150       748   86.234493
# 261   BP-0650       974   49.994489
# 265   BP-1200       338   29.042984
# 267   BR-0050       924   45.078635
# 269   BS-0650       450   42.937273
# 280   BT-0200      1266   83.098461
# 292   CA-0750      3272  135.001959
# 321   CC-2100       554   54.164715
# ...

# %%
qb_df = pd.read_csv("/home/juliet/src/football/data/superNovaOut/TE.txt", header=None, sep="\t",
                    names=["pid", "season", "totalPts", "stdDev"])
qb_df[te_df.season==2014][["pid", "totalPts", "stdDev"]]
# Out:
#           pid  totalPts      stdDev
# 13    AC-1650         0    0.000000
# 32    AF-0200      1134   58.917315
# 44    AG-0500      3506  126.513818
# 62    AQ-0100      1208   54.125255
# 66    AR-1160       278   46.073914
# 67    AS-0550       206   40.374482
# 100   BB-2450       252   63.000000
# 108   BC-0700       446   30.189958
# 149   BL-0950       268   43.632978
# 173   BM-3800       104    4.265952
# 181   BP-0200       252   63.000000
# 191   BP-0600        42    2.642797
# 219   BW-0700       574   44.397152
# 224   BW-2030        22    2.400000
# 237   CB-2775         5    0.000000
# 241   CC-2100       554   54.164715
# 253   CC-3200       288   44.263416
# 274   CF-0375       133   51.207812
# 284   CF-0650      2512   89.484427
# 286   CF-0850       400   41.983330
# 290   CG-1030       274   45.215554
# 292   CG-1650       312   52.804672
# 297   CH-1200       420   46.185616
# 300   CH-1230       280   42.184120
# 301   CH-2350       572   52.642986
# ...

# %%
wr_df = pd.read_csv("/home/juliet/src/football/data/superNovaOut/WR.txt", header=None, sep="\t",
                    names=["pid", "season", "totalPts", "stdDev"])
wr_df[wr_df.season==2014][["pid", "totalPts", "stdDev"]]
# Out:
#           pid  totalPts      stdDev
# 38    AB-2000      1884   65.526593
# 44    AB-3500      4604  103.769574
# 60    AC-0100        26    2.948111
# 83    AD-1450        18    1.479020
# 99    AG-1500      2166   73.899848
# 111   AH-1900       998   48.162872
# 114   AH-3600      1412   79.451844
# 115   AH-3900       932   93.140687
# 120   AJ-0430      3194   77.065896
# 123   AJ-0460        52    4.027682
# 138   AJ-0900      1052   49.687647
# 163   AP-0900       318   54.508600
# 179   AR-1100       774   41.477733
# 182   AR-1200         2    0.500000
# 183   AR-1250       413   53.256079
# 185   AS-0150        30    2.362908
# 186   AT-0350         8   10.495713
# 205   AW-1650        75    9.098105
# 217   BB-2050       342   34.391068
# 220   BB-4100       664   46.539428
# 231   BC-2325       686   89.777726
# 242   BE-0350       402   94.342624
# 269   BG-0600       418   31.880277
# 282   BH-0800       782   41.027382
# 306   BL-0100      2382  101.105926
# ...
